# %%
import numpy as np

# %%
arr = np.random.randint(1,10,(3,2))
arr.shape
arr
# Out:
# array([[5, 5],
#        [3, 1],
#        [7, 2]])

# %%
arr.reshape(1,6) #cambia la forma del array
# Out:
# array([[6, 8, 9, 9, 8, 2]])

# %%
arr.reshape(2,3)
# Out:
# array([[5, 5, 3],
#        [1, 7, 2]])

# %%
np.reshape(arr,(1,6))
# Out:
# array([[5, 5, 3, 1, 7, 2]])

# %%
np.reshape(arr,(2,3),'C') #como lenguaje C, base de Python!
# Out:
# array([[5, 5, 3],
#        [1, 7, 2]])

# %%
np.reshape(arr,(2,3),'F') #como lenguaje Fortran
# Out:
# array([[5, 7, 1],
#        [3, 5, 2]])

# %%
np.reshape(arr,(2,3),'A') #como mejor esté optimizado en memoria
# Out:
# array([[5, 5, 3],
#        [1, 7, 2]])
